# %%
import sys
import joblib
import numpy
import matplotlib
import seaborn
import pandas

# %%
sys.path.append(r"C:\Users\dell\OneDrive\Documents\VS Codes\Udacity-UD120-Migrated-to-Python-3\tools")
from feature_format import featureFormat, targetFeatureSplit
from tester import dump_classifier_and_data

# %%
#creating dataframe

with open(r"C:\Users\dell\OneDrive\Documents\VS Codes\Udacity-UD120-Migrated-to-Python-3\final_project\final_project_dataset.pkl","rb") as data:
    datadict = joblib.load(data)
datadict
# Out:
# {'METTS MARK': {'salary': 365788,
#   'to_messages': 807,
#   'deferral_payments': 'NaN',
#   'total_payments': 1061827,
#   'loan_advances': 'NaN',
#   'bonus': 600000,
#   'email_address': 'mark.metts@enron.com',
#   'restricted_stock_deferred': 'NaN',
#   'deferred_income': 'NaN',
#   'total_stock_value': 585062,
#   'expenses': 94299,
#   'from_poi_to_this_person': 38,
#   'exercised_stock_options': 'NaN',
#   'from_messages': 29,
#   'other': 1740,
#   'from_this_person_to_poi': 1,
#   'poi': False,
#   'long_term_incentive': 'NaN',
#   'shared_receipt_with_poi': 702,
#   'restricted_stock': 585062,
#   'director_fees': 'NaN'},
#  'BAXTER JOHN C': {'salary': 267102,
#   'to_messages': 'NaN',
#   'deferral_payments': 1295738,
#   'total_payments': 5634343,
#   'loan_advances': 'NaN',
#   'bonus': 1200000,
#   'email_address': 'NaN',
#   'restricted_stock_deferred': 'NaN',
#   'deferred_income': -1386055,
#   'total_stock_value': 10623258,
#   'expenses': 11200,
# ...

# %%
# Changing the orientation of the Dataframe for better EDA.
dataframe = pandas.DataFrame.from_dict(datadict,orient="index")
dataframe
# Out:
#                       salary to_messages deferral_payments total_payments  \
# METTS MARK            365788         807               NaN        1061827
# BAXTER JOHN C         267102         NaN           1295738        5634343
# ELLIOTT STEVEN        170941         NaN               NaN         211725
# CORDES WILLIAM R         NaN         764               NaN            NaN
# HANNON KEVIN P        243293        1045               NaN         288682
# ...                      ...         ...               ...            ...
# GRAMM WENDY L            NaN         NaN               NaN         119292
# CAUSEY RICHARD A      415189        1892               NaN        1868758
# TAYLOR MITCHELL S     265214         533            227449        1092663
# DONAHUE JR JEFFREY M  278601         865               NaN         875760
# GLISAN JR BEN F       274975         873               NaN        1272284
#
#                      loan_advances    bonus              email_address  \
# ...

# %%
#Converting all objects to float64 so that it can handle NaN values

columns = dataframe.columns
str_columns = ['email_address','poi']

for i in columns:
    if i in str_columns:
        continue
    else:
        dataframe[i] = dataframe[i].astype('float64')

dataframe.describe()
# Out:
#              salary   to_messages  deferral_payments  total_payments  \
# count  9.500000e+01     86.000000       3.900000e+01    1.250000e+02
# mean   5.621943e+05   2073.860465       1.642674e+06    5.081526e+06
# std    2.716369e+06   2582.700981       5.161930e+06    2.906172e+07
# min    4.770000e+02     57.000000      -1.025000e+05    1.480000e+02
# 25%    2.118160e+05    541.250000       8.157300e+04    3.944750e+05
# 50%    2.599960e+05   1211.000000       2.274490e+05    1.101393e+06
# 75%    3.121170e+05   2634.750000       1.002672e+06    2.093263e+06
# max    2.670423e+07  15149.000000       3.208340e+07    3.098866e+08
#
#        loan_advances         bonus  restricted_stock_deferred  \
# count   4.000000e+00  8.200000e+01               1.800000e+01
# mean    4.196250e+07  2.374235e+06               1.664106e+05
# std     4.708321e+07  1.071333e+07               4.201494e+06
# min     4.000000e+05  7.000000e+04              -7.576788e+06
# ...

# %%
# Dropping unnecessary values and columns
dataframe.drop("TOTAL",axis=0,inplace=True)

# %%
dataframe.drop('loan_advances',axis=1,inplace=True)
dataframe
# Out:
#                         salary  to_messages  deferral_payments  \
# METTS MARK            365788.0        807.0                NaN
# BAXTER JOHN C         267102.0          NaN          1295738.0
# ELLIOTT STEVEN        170941.0          NaN                NaN
# CORDES WILLIAM R           NaN        764.0                NaN
# HANNON KEVIN P        243293.0       1045.0                NaN
# ...                        ...          ...                ...
# GRAMM WENDY L              NaN          NaN                NaN
# CAUSEY RICHARD A      415189.0       1892.0                NaN
# TAYLOR MITCHELL S     265214.0        533.0           227449.0
# DONAHUE JR JEFFREY M  278601.0        865.0                NaN
# GLISAN JR BEN F       274975.0        873.0                NaN
#
#                       total_payments      bonus              email_address  \
# METTS MARK                 1061827.0   600000.0       mark.metts@enron.com
# ...

# %%
dataframe['restricted_stock_deferred'].describe()
# Out:
# count    1.700000e+01
# mean     6.218928e+05
# std      3.845528e+06
# min     -1.787380e+06
# 25%     -3.298250e+05
# 50%     -1.402640e+05
# 75%     -7.241900e+04
# max      1.545629e+07
# Name: restricted_stock_deferred, dtype: float64

# %%
dataframe.drop('restricted_stock_deferred',axis=1,inplace=True)
dataframe
# Out:
#                         salary  to_messages  deferral_payments  \
# METTS MARK            365788.0        807.0                NaN
# BAXTER JOHN C         267102.0          NaN          1295738.0
# ELLIOTT STEVEN        170941.0          NaN                NaN
# CORDES WILLIAM R           NaN        764.0                NaN
# HANNON KEVIN P        243293.0       1045.0                NaN
# ...                        ...          ...                ...
# GRAMM WENDY L              NaN          NaN                NaN
# CAUSEY RICHARD A      415189.0       1892.0                NaN
# TAYLOR MITCHELL S     265214.0        533.0           227449.0
# DONAHUE JR JEFFREY M  278601.0        865.0                NaN
# GLISAN JR BEN F       274975.0        873.0                NaN
#
#                       total_payments      bonus              email_address  \
# METTS MARK                 1061827.0   600000.0       mark.metts@enron.com
# ...

# %%
dataframe['director_fees'].describe()
# Out:
# count        16.000000
# mean      89822.875000
# std       41112.700735
# min        3285.000000
# 25%       83674.500000
# 50%      106164.500000
# 75%      112815.000000
# max      137864.000000
# Name: director_fees, dtype: float64

# %%
dataframe.drop('director_fees',axis=1,inplace=True)
dataframe
# Out:
#                         salary  to_messages  deferral_payments  \
# METTS MARK            365788.0        807.0                NaN
# BAXTER JOHN C         267102.0          NaN          1295738.0
# ELLIOTT STEVEN        170941.0          NaN                NaN
# CORDES WILLIAM R           NaN        764.0                NaN
# HANNON KEVIN P        243293.0       1045.0                NaN
# ...                        ...          ...                ...
# GRAMM WENDY L              NaN          NaN                NaN
# CAUSEY RICHARD A      415189.0       1892.0                NaN
# TAYLOR MITCHELL S     265214.0        533.0           227449.0
# DONAHUE JR JEFFREY M  278601.0        865.0                NaN
# GLISAN JR BEN F       274975.0        873.0                NaN
#
#                       total_payments      bonus              email_address  \
# METTS MARK                 1061827.0   600000.0       mark.metts@enron.com
# ...
