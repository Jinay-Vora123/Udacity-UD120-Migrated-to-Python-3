# %%
import sys
import pickle
import numpy
import matplotlib
import seaborn
import pandas

# %%
sys.path.append(r"C:\Users\dell\OneDrive\Documents\VS Codes\Udacity-UD120-Migrated-to-Python-3\tools")
from feature_format import featureFormat, targetFeatureSplit
from tester import dump_classifier_and_data

# %%
#creating dataframe

with open(r"C:\Users\dell\OneDrive\Documents\VS Codes\Udacity-UD120-Migrated-to-Python-3\final_project\final_project_dataset.pkl","rb") as data:
    dataframe = pandas.DataFrame.from_dict(pickle.load(data))
dataframe
# Out:
#                                      METTS MARK BAXTER JOHN C  \
# salary                                   365788        267102
# to_messages                                 807           NaN
# deferral_payments                           NaN       1295738
# total_payments                          1061827       5634343
# loan_advances                               NaN           NaN
# bonus                                    600000       1200000
# email_address              mark.metts@enron.com           NaN
# restricted_stock_deferred                   NaN           NaN
# deferred_income                             NaN      -1386055
# total_stock_value                        585062      10623258
# expenses                                  94299         11200
# from_poi_to_this_person                      38           NaN
# exercised_stock_options                     NaN       6680544
# from_messages                                29           NaN
# ...

# %%
print(dataframe['METTS MARK'])
# Out:
# salary                                     365788
# to_messages                                   807
# deferral_payments                             NaN
# total_payments                            1061827
# loan_advances                                 NaN
# bonus                                      600000
# email_address                mark.metts@enron.com
# restricted_stock_deferred                     NaN
# deferred_income                               NaN
# total_stock_value                          585062
# expenses                                    94299
# from_poi_to_this_person                        38
# exercised_stock_options                       NaN
# from_messages                                  29
# other                                        1740
# from_this_person_to_poi                         1
# poi                                         False
# long_term_incentive                           NaN
# shared_receipt_with_poi                       702
# ...

# %%
dataframe
